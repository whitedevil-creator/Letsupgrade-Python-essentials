# %% [markdown]
#  QUESTION NO 1

# %%
def getInput(calculate_arg_fun):
    
    def wrap_function():
    
        a = int(input("\nEnter First Number - "))
        
        b = int(input("\nEnter Second Number - "))
        
        calculate_arg_fun(a,b)   
    
    return wrap_function

# %%
@getInput
 
def EvenFinder(start, last):
    
    print("\nThe Even numbers in the range",start,"to",last,"is :\n")
 
    for n in range(start, last + 1): 
      
        if n % 2 == 0: 
            
            print(n, end = " ")

# %%
EvenFinder()
# Out:
# Enter First Number - 35
#
# Enter Second Number - 73
#
# The Even numbers in the range 35 to 73 is :
#
# 36 38 40 42 44 46 48 50 52 54 56 58 60 62 64 66 68 70 72

# %% [markdown]
# QUESTION NO 2

# %%
# %%writefile test.txt
#
# Hi this is sai,i teach in letsupgrade
# Out:
# Overwriting test.txt

# %%
f = open("test.txt",'r')
f.read()
# Out:
# ' \nHi this is sai,i teach in letsupgrade'

# %%
try:
    f.write("my first file\n")
except:
    print("unable to write to file due to the read mode of file")
finally:
    f.close()
# Out:
# unable to write to file due to the read mode of file
