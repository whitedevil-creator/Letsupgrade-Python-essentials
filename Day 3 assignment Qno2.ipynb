# %% [markdown]
# Assignment of day 3
#
# Question no 1

# %%
 
 
# we all are the pilots
# we have to land plane safely
 
 i = 1000
   
if i<=1000:
       print("land the plane")
elif i<=5000:
     print("bring down to 1000ft")
else:
     print("turn around the plane")
# Out:
# land the plane

# %%
 i = 4500
   
if i<=1000:
       print("land the plane")
elif i<=5000:
     print("bring down to 1000ft")
else:
     print("turn around the plane")
# Out:
# bring down to 1000ft

# %%
 i = 6500
   
if i<=1000:
       print("land the plane")
elif i<=5000:
     print("bring down to 1000ft")
else:
     print("turn around the plane")
# Out:
# turn around the plane
