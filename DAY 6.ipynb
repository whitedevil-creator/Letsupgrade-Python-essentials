# %% [markdown]
# QUESTION NO 1

# %%
class bank:
    def __init__(self,ownername,balance):
        self.ownername = ownername
        self.balance = balance

    def deposit(self,amount):
        self.balance +=amount
        print("your updated balance is :", self.balance)
        
    def withdraw(self,amount):
        if(self.balance>amount):
            self.balance-=amount
            print("your updated balance is :", self.balance)
        else:
            print("you don't have enough cradit in your account, see you have only",self.balance)

# %%
rathee = bank("Ratheesingh",45000)

# %%
rathee.withdraw(5000)
# Out:
# your updated balance is : 40000

# %%
rathee.deposit(10000)
# Out:
# your updated balance is : 50000

# %%
rathee.withdraw(100000)
# Out:
# you don't have enough cradit in your account, see you have only 50000

# %% [markdown]
# QUESTION NO 2

# %%
import math

pi = math.pi

class cone:
    
    def __init__(self,r,h): 

        self.r=r
        
        self.h=h
        
    def volume(self):
        
        result = (1 / 3) * pi * self.r * self.r * self.h
        
        print("\nVolume Of Cone is :",result)
        
    def surfacearea(self):
        
        result = pi * self.r * self.h + pi * self.r * self.r
         
        print("\nSurface Area Of Cone is :",result)

# %%
ra = float(input("\nEnter the radius of cone : "))

he = float(input("\nEnter the height of cone : "))

c = cone( ra, he)

c.volume()

c.surfacearea()
# Out:
# Enter the radius of cone : 15
#
# Enter the height of cone : 10
#
# Volume Of Cone is : 2356.1944901923443
#
# Surface Area Of Cone is : 1178.0972450961724
